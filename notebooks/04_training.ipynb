# %% [markdown]
# # Training Pipeline
#
# Complete training pipeline with checkpointing and monitoring.

# %%
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
import yaml
from pathlib import Path

# Load configuration
with open('../config/config.yaml', 'r') as f:
    config = yaml.safe_load(f)

print("Configuration loaded:")
print(f"Epochs: {config['training']['epoch']}")
print(f"Learning rate: {config['training']['learning_rate']}")
print(f"Batch size: {config['data']['batch_size']}")

# %%
import sys
sys.path.insert(0, '../src')
from models import MultimodalHealthcareModel
from train import train_epoch, validate

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MultimodalHealthcareModel(tabular_dim=config['model']['tabular_dim'])
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=config['training']['learning_rate'])

print(f"Model initialized on {device}")

# %%
# Training loop structure
num_epochs = config['training']['epoch']
checkpoint_dir = Path('../checkpoints')

print(f"Starting training for {num_epochs} epochs")
print(f"Checkpoints will be saved to: {checkpoint_dir}")

# Placeholder for actual training
train_losses = []
val_losses = []

print("Training setup complete. Ready to begin training.")

# %%
# Plotting training curves
import matplotlib.pyplot as plt

print("Training curves will be plotted here after training completes.")
