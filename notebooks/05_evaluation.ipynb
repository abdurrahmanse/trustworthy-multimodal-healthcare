# %% [markdown]
# # Model Evaluation
#
# Comprehensive evaluation of trained models using healthcare-specific metrics.

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

device = torch.device(
    "mps" if torch.backends.mps.is_available()
    else "cuda" if torch.cuda.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
from evaluate import HealthcareModelEvaluator
import sys
sys.path.insert(0, '../src')

evaluator = HealthcareModelEvaluator()
print("Evaluator initialized")

# %%
# Placeholder for evaluation metrics
print("Evaluation metrics will include:")
print("- Accuracy")
print("- Precision")
print("- Recall")
print("- F1-Score")
print("- AUC-ROC")
print("- Sensitivity & Specificity")
print("- Confusion Matrix")

# %%
# Confusion matrix visualization template
print("Confusion matrix visualization will be generated here.")

# %%
# ROC curve visualization template
print("ROC curve will be plotted here.")

# %%
# Comparison of baseline vs multimodal models
print("Model comparison table will be generated here.")
