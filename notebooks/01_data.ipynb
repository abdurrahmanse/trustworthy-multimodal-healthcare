# %% [markdown]
# # Data Exploration and Analysis
#
# This notebook performs exploratory data analysis on the multimodal healthcare dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('../data/master_dataset.csv')
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (5, 9)
#   patient_id  age gender  visit_date          medical_history  \
# 0       P001   45      M  2024-01-15    hypertension;diabetes
# 1       P002   62      F  2024-01-16           asthma;obesity
# 2       P003   38      M  2024-01-17          smoking_history
# 3       P004   71      F  2024-01-18  heart_disease;arthritis
# 4       P005   55      M  2024-01-19             hypertension
#
#                    lab_results        imaging_data       diagnosis  severity
# 0  glucose:120;hemoglobin:13.5      chest_xray.jpg          normal       low
# 1  glucose:145;hemoglobin:12.8         ct_scan.jpg       pneumonia      high
# 2   glucose:95;hemoglobin:14.2        lung_mri.jpg         healthy       low
# 3  glucose:118;hemoglobin:13.1  echocardiogram.jpg  cardiomyopathy  critical
# 4  glucose:102;hemoglobin:13.9       brain_mri.jpg          normal       low

# %%
# Basic statistics
df.describe()
# Out:
#              age
# count   5.000000
# mean   54.200000
# std    13.141537
# min    38.000000
# 25%    45.000000
# 50%    55.000000
# 75%    62.000000
# max    71.000000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# patient_id         0
# age                0
# gender             0
# visit_date         0
# medical_history    0
# lab_results        0
# imaging_data       0
# diagnosis          0
# severity           0
# dtype: int64

# %%
# Diagnosis distribution
plt.figure(figsize=(10, 5))
df['diagnosis'].value_counts().plot(kind='bar')
plt.title('Diagnosis Distribution')
plt.show()

# %%
# Age distribution
plt.figure(figsize=(10, 5))
df['age'].hist(bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
