# %% [markdown]
# # Multimodal Model Development
#
# Build and train multimodal neural networks combining tabular, image, and text data.

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from pathlib import Path

# Check device
device = torch.device(
    "mps" if torch.backends.mps.is_available()
    else "cuda" if torch.cuda.is_available()
    else "cpu"
)

print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
# Import custom models
import sys
sys.path.insert(0, '../src')
from models import MultimodalHealthcareModel, TabularEncoder, ImageEncoder, TextEncoder

# Initialize model
model = MultimodalHealthcareModel(tabular_dim=5, num_classes=2)
model = model.to(device)
print(f"Model initialized on {device}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import sys
#       3 sys.path.insert(0, '../src')
# ----> 4 from models import MultimodalHealthcareModel, TabularEncoder, ImageEncoder, TextEncoder
#       6 # Initialize model
#       7 model = MultimodalHealthcareModel(tabular_dim=5, num_classes=2)
#
# File /Volumes/Fullstack/Github Clone /trustworthy-multimodal-healthcare/notebooks/../src/models.py:7
#       5 import torch
#       6 import torch.nn as nn
# ----> 7 from transformers import AutoModel, AutoTokenizer
#      10 class TabularEncoder(nn.Module):
#      11     """Encode tabular health data."""
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# Model summary
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total trainable parameters: {count_parameters(model):,}")

# %%
# Training setup
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

print("Training configuration:")
print(f"Loss function: CrossEntropyLoss")
print(f"Optimizer: Adam (lr=1e-3)")

# %%
# Placeholder training loop
num_epochs = 10
print(f"Ready to train for {num_epochs} epochs")
print("(Actual training would require prepared DataLoaders)")
